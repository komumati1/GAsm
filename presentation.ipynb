# %%
from utils import load_json_file, plot_hist_from_json
from data_generators import gen_binop_sum_sub_mul
from data_generators import gen_max_dataset
# Qwen , kitty, nuscenes, moe, 235B

# %%
import gasm

def test_models(test_case, num1, num2):
    SENT = 1234567.89
    g = gasm.GAsm.fromJson(f"example_data/example_{test_case}.json")
    hist = g.hist
    best_individual = g.best

    inputs = [SENT for _ in range(10)]

    inputs[0] = float(num1)
    inputs[1] = float(num2)

    print(f"Input: {[int(x) for x in inputs]}")
    time = best_individual.run(inputs)
    print(f"Result: {[int(x) for x in inputs]}")
    print(best_individual.toString())

# %% [markdown]
# # Zadanie 1.2 C - dodawanie

# %%
data = load_json_file('example_data/example_1_2_C_1.json')

plot_hist_from_json(hist_json=data['history'])

# %% [markdown]
# ## Przykładowe dane (trenowane na zakresie -10,10)

# %%
inputs, targets = gen_binop_sum_sub_mul("sum", n_random=800, buf=10, seed=1)
print("Sample inputs and targets:")
for i in range(5):
    print(f"Input: {[int(num) for num in inputs[i]]} => Target: {[int(num) for num in targets[i]]}")
# Out:
# Sample inputs and targets:
# Input: [-10, -10, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567] => Target: [-20]
# Input: [-10, -9, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567] => Target: [-19]
# Input: [-10, -1, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567] => Target: [-11]
# Input: [-10, 0, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567] => Target: [-10]
# Input: [-10, 1, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567] => Target: [-9]

# %% [markdown]
# ## Przykład

# %%
test_models("1_2_C_1", 37, 33)
# Out:
# Input: [37, 33, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567]
# Result: [70, 33, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567]
# SUB I
# JMP P
# SIN R
# MUL R
# SUB I
# LOP P
# COS I
# SET
# COS I
# END
# MOV A, I
# INC
# ADD I
# END
# RES
# MOV A, I
# END
# MOV A, I
# INC
# ADD I
# END
# RES
# LOP P
# LOP A
# SUB R
# LOP P
# MOV I, A

# %% [markdown]
# # Zadanie 1.2 D - odejmowanie

# %%
data = load_json_file('example_data/example_1_2_D_2.json')

plot_hist_from_json(hist_json=data['history'])

# %% [markdown]
# ## Przykładowe dane (trenowane na zakresie -10,10)

# %%
inputs, targets = gen_binop_sum_sub_mul("sub", n_random=800, buf=10, seed=1)
print("Sample inputs and targets:")
for i in range(5):
    print(f"Input: {[int(num) for num in inputs[i]]} => Target: {[int(num) for num in targets[i]]}")
# Out:
# Sample inputs and targets:
# Input: [-10, -10, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567] => Target: [0]
# Input: [-10, -9, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567] => Target: [-1]
# Input: [-10, -1, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567] => Target: [-9]
# Input: [-10, 0, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567] => Target: [-10]
# Input: [-10, 1, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567] => Target: [-11]

# %% [markdown]
# ## Przykładowy program

# %%
test_models("1_2_D_2", 33, 37)
# Out:
# Input: [33, 37, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567]
# Result: [-4, 37, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567]
# DIV I
# INC
# MOV A, I
# ADD I
# RES
# INC
# INC
# MOV A, I
# ADD I
# RES
# INC
# MOV P, A
# MUL R
# RNG
# SIN R
# DIV I
# LOP A
# SUB R
# SIN R
# RES
# ADD I
# RES
# INC
# SUB I
# RES
# MOV I, A
# LOP A
# MOV R, A
# LOP P
# ADD R
# DIV I
# RES
# FOR
# DEC
# JMP P
# RES
# INC
# MOV R, A
# RES
# LOP P
# MUL I
# MOV R, A
# LOP P
# ADD R
# DIV I
# RES
# FOR
# DEC
# JMP P
# RES

# %% [markdown]
# # Zadanie 1.2 E - iloczyn (trenowane na zakresie -10,10)

# %%
data = load_json_file('example_data/example_1_2_E_1.json')

plot_hist_from_json(hist_json=data['history'])

# %% [markdown]
# ## Przykładowe dane (trenowane na zakresie -10,10)

# %%
inputs, targets = gen_binop_sum_sub_mul("mul", n_random=800, buf=10, seed=1)
print("Sample inputs and targets:")
for i in range(5):
    print(f"Input: {[int(num) for num in inputs[i]]} => Target: {[int(num) for num in targets[i]]}")
# Out:
# Sample inputs and targets:
# Input: [-10, -10, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567] => Target: [100]
# Input: [-10, -9, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567] => Target: [90]
# Input: [-10, -1, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567] => Target: [10]
# Input: [-10, 0, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567] => Target: [0]
# Input: [-10, 1, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567] => Target: [-10]

# %% [markdown]
# ## Przykładowy program

# %%
test_models("1_2_E_1", 4, 2)
# Out:
# Input: [4, 2, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567]
# Result: [8, 2, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567]
# RES
# SUB R
# MOV A, P
# INC
# MOV R, A
# SIN I
# EXP R
# MOV A, I
# RES
# MUL I
# MOV I, A
# SIN I
# INC
# MUL R
# RNG
# EXP R
# JMP P

# %% [markdown]
# # Zadanie 1.3 A - wybranie większej liczby spośród dwóch

# %%
data = load_json_file('example_data/example_1_3_A_1.json')

plot_hist_from_json(hist_json=data['history'])

# %% [markdown]
# # Zadanie 1.3 A - max z dwóch pierwszych liczb (trenowane na zakresie -50,50)

# %%
inputs, targets = gen_max_dataset(lo=-50, hi=50, n=800, buf=10, seed=42)
print("Sample inputs and targets:")
for i in range(5):
    print(f"Input: {[int(num) for num in inputs[i]]} => Target: {[int(num) for num in targets[i]]}")
# Out:
# Sample inputs and targets:
# Input: [-50, -50, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567] => Target: [-50]
# Input: [-50, -49, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567] => Target: [-49]
# Input: [-50, -1, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567] => Target: [-1]
# Input: [-50, 0, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567] => Target: [0]
# Input: [-50, 1, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567] => Target: [1]

# %% [markdown]
# ## Przykładowy program

# %%
test_models("1_3_A_1", 37, 33)
# Out:
# Input: [37, 33, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567]
# Result: [37, 33, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567, 1234567]
# RNG
# MUL R
# SUB I
# RES
# RNG
# COS I
# SUB I
# RES
# RES
# SET
# ADD I
# INC
# EXP R
# MUL I
# RES
# RES
# SUB I
# COS I
# SUB I
# RES
# RES
# SET
# ADD I
# INC
# EXP R
# MUL I
# RES
# RES
# SUB I
# RES
# JMP P
# ADD I
# MOV I, A
# SIN I
# SET
# ADD I
# INC
# EXP R
# MUL I
# RES
# RES
# JMP P
# MOV I, A
# RES
# JMP P
# EXP R
# SUB R
# INC
# RES
# MUL R
